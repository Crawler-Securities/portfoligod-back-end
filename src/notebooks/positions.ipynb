# %%
from src import config
baseUrl = config.CPAPI_GATEWAY_URL
import requests
# Out:
# Z:\code\protfoli-god\portfoligod-back-end\venv\Lib\site-packages\urllib3\connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
res = requests.get(baseUrl + '/portfolio/accounts', verify=False)
accountId = res.json()[0]['accountId']
posRes = requests.get(baseUrl + f'/portfolio/{accountId}/positions/0?direction=a&period=1W&sort=position&model=MyModel', verify=False)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File Z:\code\protfoli-god\portfoligod-back-end\venv\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File Z:\Program Files\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
# ...

# %%
posRes.json()
# Out:
# [{'acctId': 'U10384522',
#   'conid': 320227571,
#   'contractDesc': 'QQQ',
#   'position': 1.0,
#   'mktPrice': 414.20999145,
#   'mktValue': 414.21,
#   'currency': 'USD',
#   'avgCost': 410.395,
#   'avgPrice': 410.395,
#   'realizedPnl': 0.0,
#   'unrealizedPnl': 3.81,
#   'exchs': None,
#   'expiry': None,
#   'putOrCall': None,
#   'multiplier': 0.0,
#   'strike': '0',
#   'exerciseStyle': None,
#   'conExchMap': [],
#   'assetClass': 'STK',
#   'undConid': 0,
#   'model': 'MyModel',
#   'baseMktValue': 414.21,
#   'baseMktPrice': 414.20999145,
#   'baseAvgCost': 410.395,
#   'baseAvgPrice': 410.395,
#   'baseRealizedPnl': 0.0,
#   'baseUnrealizedPnl': 3.81,
#   'incrementRules': [{'lowerEdge': 0.0, 'increment': 0.01}],
#   'displayRule': {'magnification': 0,
#    'displayRuleStep': [{'decimalDigits': 2,
#      'lowerEdge': 0.0,
#      'wholeDigits': 4}]},
#   'time': 28,
#   'chineseName': '&#x666F;&#x987A; QQQ&#x4FE1;&#x6258;&#x7CFB;&#x5217;1',
# ...
